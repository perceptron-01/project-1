# %% [markdown]
# <a href="https://colab.research.google.com/github/perceptron-01/project-1/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
final=pd.DataFrame()
for j in range(1,501):
    response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=2e05d0045292780824e039bd4acd6c8f&language=en-US&page={}'.format(j)).json()
    popularity=[]
    vote_count=[]
    original_language=[]
    title=[]
    vote_average=[]
    overview=[]
    release_date=[]

    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        overview.append(i['overview'])
        release_date.append(i['release_date'])

    d={'title':title, 'overview':overview, 'original_language':original_language, 'ralease_date':release_date, 'popularity':popularity, 'vote_count':vote_count, 'vote_average':vote_average}
    df=pd.DataFrame(d)
    # Use pd.concat instead of append
    final = pd.concat([final, df], ignore_index=True)

# %%
response['total_results']
# Out:
# 957140

# %%
final.shape
# Out:
# (10000, 7)

# %%
file_path = r'C:\Users\Aman\Downloads\popular_movies.csv'
final.to_csv(file_path, index=True)

# %%
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]

for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['vote_average'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])

d={'title':title, 'overview':overview, 'original_language':original_language, 'ralease_date':release_date, 'popularity':popularity, 'vote_count':vote_count, 'vote_average':vote_average}
df=pd.DataFrame(d)
df
# Out:
#                                           title  \
# 0                                       Red One
# 1                         Venom: The Last Dance
# 2                         Mufasa: The Lion King
# 3                                       Moana 2
# 4                          Sonic the Hedgehog 3
# 5                                      Carry-On
# 6                                  Gladiator II
# 7                                  Dirty Angels
# 8                                     Elevation
# 9                                    Culpa tuya
# 10                                   Absolution
# 11  The Price of Money: A Largo Winch Adventure
# 12                               The Wild Robot
# 13                            Kraven the Hunter
# 14               How the Grinch Stole Christmas
# 15                                  Terrifier 3
# 16                                        Anora
# 17                                     My Fault
# 18                               That Christmas
# 19                                The Substance
#
#                                              overview original_language  \
# 0   After Santa Claus (codename: Red One) is kidna...                en
# 1   Eddie and Venom are on the run. Hunted by both...                en
# 2   Told in flashbacks, Mufasa is an orphaned cub,...                en
# 3   After receiving an unexpected call from her wa...                en
# 4   Sonic, Knuckles, and Tails reunite against a p...                en
# 5   An airport security officer races to outsmart ...                en
# 6   Years after witnessing the death of the revere...                en
# 7   During the United States' 2021 withdrawal from...                en
# 8   A single father and two women venture from the...                en
# 9   The love between Noah and Nick seems unwaverin...                es
# 10  An aging ex-boxer gangster working as muscle f...                en
# 11  Largo Winch, devastated by the kidnapping of h...                fr
# 12  After a shipwreck, an intelligent robot called...                en
# 13  Kraven Kravinoff's complex relationship with h...                en
# 14  The Grinch decides to rob Whoville of Christma...                en
# 15  Five years after surviving Art the Clown's Hal...                en
# 16  A young sex worker from Brooklyn gets her chan...                en
# 17  Noah must leave her city, boyfriend, and frien...                es
# 18  It's an unforgettable Christmas for the townsf...                en
# 19  A fading celebrity decides to use a black mark...                en
#
#    ralease_date  popularity  vote_count  vote_average
# 0    2024-10-31    6261.101        1396         6.991
# 1    2024-10-22    4456.747        1870         6.796
# 2    2024-12-18    3139.872         215         6.998
# 3    2024-11-21    2811.069         603         6.939
# 4    2024-12-19    2616.669         114         7.846
# 5    2024-12-05    2381.948         989         7.000
# 6    2024-11-05    2140.002        1387         6.700
# 7    2024-12-11    1997.336          35         6.371
# 8    2024-11-07    1625.929         192         6.300
# 9    2024-12-26    1442.594           9         7.100
# 10   2024-10-31    1211.368         176         6.142
# 11   2024-07-31    1121.824          60         5.800
# 12   2024-09-08    1040.825        3619         8.383
# 13   2024-12-11    1005.522         209         5.800
# 14   2000-11-17     939.537        7545         6.772
# 15   2024-10-09     864.902        1294         6.880
# 16   2024-10-14     845.980         507         7.160
# 17   2023-06-08     835.404        3157         7.910
# 18   2024-11-27     818.812         240         7.200
# 19   2024-09-07     817.984        2763         7.200

# %%
d = {'name':['rahul', 'rohit'],'age':[25,28]}
df = pd.DataFrame(d)
# Out:
#     name  age
# 0  rahul   25
# 1  rohit   28
